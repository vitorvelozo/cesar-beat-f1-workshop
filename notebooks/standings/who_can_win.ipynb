# %%
import fastf1 as ff1
from fastf1.ergast import Ergast

# %%
SEASON = 2025
ROUND = 23

# %%
def get_drivers_standings():
    ergast = Ergast()
    standings = ergast.get_driver_standings(season=SEASON, round=ROUND)
    return standings.content[0]

# %%
def calculate_max_points_for_remaining_season() -> int:
    POINTS_FOR_SPRINT = 8 + 25
    POINTS_FOR_CONVENTIONAL = 25

    events = ff1.events.get_event_schedule(SEASON, backend='ergast')
    events = events[events['RoundNumber'] > ROUND]

    sprint_events = len(events.loc[events["EventFormat"] == "sprint_shootout"])
    conventional_events = len(events.loc[events["EventFormat"] == "conventional"])

    sprint_points = sprint_events * POINTS_FOR_SPRINT
    conventional_points = conventional_events * POINTS_FOR_CONVENTIONAL

    return sprint_points + conventional_points

# %%
def calculate_who_can_win(driver_standings, max_points) -> None:
    LEADER_POINTS = int(driver_standings.loc[0]["points"])

    for i, _ in enumerate(driver_standings.iterrows()):
        driver = driver_standings.loc[i]
        driver_max_points = int(driver["points"]) + max_points
        can_win = "No" if driver_max_points < LEADER_POINTS else "Yes"

        print(f"{driver['position']}: {driver['givenName'] + ' ' + driver['familyName']}, "
              f"Current points: {driver['points']}, "
              f"Theoretical max points: {driver_max_points}, "
              f"Can win: {can_win}")

# %%
driver_standings = get_drivers_standings()
points = calculate_max_points_for_remaining_season()
calculate_who_can_win(driver_standings, points)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (504.03 MB) C:\Users\Vitor\AppData\Local\Temp\fastf1
# 1: Lando Norris, Current points: 408.0, Theoretical max points: 433, Can win: Yes
# 2: Max Verstappen, Current points: 396.0, Theoretical max points: 421, Can win: Yes
# 3: Oscar Piastri, Current points: 392.0, Theoretical max points: 417, Can win: Yes
# 4: George Russell, Current points: 309.0, Theoretical max points: 334, Can win: No
# 5: Charles Leclerc, Current points: 230.0, Theoretical max points: 255, Can win: No
# 6: Lewis Hamilton, Current points: 152.0, Theoretical max points: 177, Can win: No
# 7: Andrea Kimi Antonelli, Current points: 150.0, Theoretical max points: 175, Can win: No
# 8: Alexander Albon, Current points: 73.0, Theoretical max points: 98, Can win: No
# 9: Carlos Sainz, Current points: 64.0, Theoretical max points: 89, Can win: No
# 10: Isack Hadjar, Current points: 51.0, Theoretical max points: 76, Can win: No
# 11: Nico Hülkenberg, Current points: 49.0, Theoretical max points: 74, Can win: No
# 12: Fernando Alonso, Current points: 48.0, Theoretical max points: 73, Can win: No
# 13: Oliver Bearman, Current points: 41.0, Theoretical max points: 66, Can win: No
# 14: Liam Lawson, Current points: 38.0, Theoretical max points: 63, Can win: No
# 15: Yuki Tsunoda, Current points: 33.0, Theoretical max points: 58, Can win: No
# 16: Esteban Ocon, Current points: 32.0, Theoretical max points: 57, Can win: No
# 17: Lance Stroll, Current points: 32.0, Theoretical max points: 57, Can win: No
# 18: Pierre Gasly, Current points: 22.0, Theoretical max points: 47, Can win: No
# 19: Gabriel Bortoleto, Current points: 19.0, Theoretical max points: 44, Can win: No
# 20: Franco Colapinto, Current points: 0.0, Theoretical max points: 25, Can win: No
# 21: Jack Doohan, Current points: 0.0, Theoretical max points: 25, Can win: No
