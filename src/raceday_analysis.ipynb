# %% [markdown]
# # Raceday

# %% [markdown]
# Note: for simplifying this analysis, let's consider that we have the same weather conditions throughout all sessions. This analysis will not involve rain.

# %% [markdown]
# ## Environment setup

# %%
import os

import fastf1 as ff1
from dotenv import load_dotenv
from fastf1 import plotting
from fastf1.logger import set_log_level

load_dotenv()

set_log_level("ERROR")
plotting.setup_mpl(mpl_timedelta_support=True, color_scheme="fastf1")

TEAM = os.getenv("TEAM")
EVENT_YEAR = int(os.getenv("EVENT_YEAR"))
ROUND = os.getenv("ROUND")

# %matplotlib widget

# %% [markdown]
# ## Aggregating and cleaning data

# %%
race = ff1.get_session(EVENT_YEAR, ROUND, "R")
race.load()

# %%
race.laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 01:13:00.002000    VER            1 0 days 00:01:59.392000
# 1   0 days 01:15:49.358000    VER            1                    NaT
# 2   0 days 01:18:31.526000    VER            1                    NaT
# 3   0 days 01:21:07.226000    VER            1                    NaT
# 4   0 days 01:23:30.835000    VER            1 0 days 00:02:23.609000
# ..                     ...    ...          ...                    ...
# 922 0 days 02:47:44.697000    BEA           87 0 days 00:01:31.366000
# 923 0 days 02:49:15.187000    BEA           87 0 days 00:01:30.490000
# 924 0 days 02:50:46.471000    BEA           87 0 days 00:01:31.284000
# 925 0 days 02:52:16.697000    BEA           87 0 days 00:01:30.226000
# 926 0 days 02:53:47.250000    BEA           87 0 days 00:01:30.553000
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# ...
